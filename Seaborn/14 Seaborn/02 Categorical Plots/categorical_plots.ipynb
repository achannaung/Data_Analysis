# %% [markdown]
# # Categorical Plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
countries_df = pd.read_csv('top_10_countries.csv')

# %%
countries_df
# Out:
#    Rank         Country    Region        Sub Region  Population % of world  \
# 0     1           China      Asia      Eastern Asia  1412600000     17.80%
# 1     2           India      Asia     Southern Asia  1386946912     17.50%
# 2     3   United States  Americas  Northern America   333073186      4.20%
# 3     4       Indonesia      Asia    Southeast Asia   271350000      3.42%
# 4     5        Pakistan      Asia     Southern Asia   225200000      2.84%
# 5     6          Brazil  Americas  Southern America   214231641      2.70%
# 6     7         Nigeria    Africa    Western Africa   211401000      2.67%
# 7     8      Bangladesh      Asia     Southern Asia   172062576      2.17%
# 8     9          Russia    Europe    Eastern Europe   146171015      1.84%
# 9    10          Mexico  Americas   Central America   126014024      1.59%
#
#         Date
# 0  31-Dec-21
# 1  18-Jan-22
# 2  18-Jan-22
# 3  31-Dec-20
# 4  01-Jul-21
# 5  18-Jan-22
# 6  01-Jul-21
# 7  18-Jan-22
# ...

# %% [markdown]
# ## Bar Plots
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
# simple barplot with seaborn
sns.barplot(x = countries_df['Region'], y=countries_df['Population'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Population'>

# %%
# Removing the confidence intervals

sns.barplot(x = countries_df['Region'], y=countries_df['Population'], ci=None)
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/802562176.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = countries_df['Region'], y=countries_df['Population'], ci=None)
# <AxesSubplot:xlabel='Region', ylabel='Population'>

# %%
# Horizontal Orientation

sns.barplot(y = countries_df['Region'], x=countries_df['Population'], ci=None, orient="h")
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/718933801.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(y = countries_df['Region'], x=countries_df['Population'], ci=None, orient="h")
# <AxesSubplot:xlabel='Population', ylabel='Region'>

# %%
# Adding data argument to reference columns by name rather than indexing the DataFrame

sns.barplot(x = 'Region', y='Population', data=countries_df, ci=None)
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/3445680051.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'Region', y='Population', data=countries_df, ci=None)
# <AxesSubplot:xlabel='Region', ylabel='Population'>

# %%
# Changing the estimator to sum, it is mean by default

sns.barplot(x = 'Region', y='Population', data=countries_df, ci=None, estimator=sum)
plt.show()
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/3471631270.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'Region', y='Population', data=countries_df, ci=None, estimator=sum)

# %%
# Adding hue

sns.barplot(x = 'Region', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region', dodge=False)
plt.show()
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/3613513454.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'Region', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region', dodge=False)

# %%
# Using matplotlib and seaborn concurrently can allow you to format your visual

plt.figure(figsize=(10,10))

sns.barplot(x = 'Country', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region')

plt.legend(loc='center')

plt.show()
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/1229646400.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'Country', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region')

# %%
# Setting dodge=False will prevent the bars from 'shifting'

plt.figure(figsize=(10,10))

sns.barplot(x = 'Country', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region', dodge=False)

plt.legend(loc='center')

plt.show()
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/183529481.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x = 'Country', y='Population', data=countries_df, estimator=sum, ci=None, hue='Region', dodge=False)

# %%
# Using subplots to plot on 2 axes

fig, (ax1,ax2) = plt.subplots(figsize=(20,10),nrows=1,ncols=2, tight_layout=True)

sns.barplot(x=countries_df['Region'],y=countries_df['Population'], ci=None, estimator=sum, ax=ax1)
sns.barplot(x=countries_df['Country'],y=countries_df['Population'], ci=None, estimator=sum, ax=ax2)

plt.show()
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/2369824516.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=countries_df['Region'],y=countries_df['Population'], ci=None, estimator=sum, ax=ax1)
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/2369824516.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=countries_df['Country'],y=countries_df['Population'], ci=None, estimator=sum, ax=ax2)

# %% [markdown]
# # Count Plot
# https://seaborn.pydata.org/generated/seaborn.countplot.html

# %%
# Count Plot uses a count estimator and takes one axis argument
sns.countplot(x=countries_df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %% [markdown]
# # Box Plots and Violin Plots
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://seaborn.pydata.org/generated/seaborn.violinplot.html

# %%
players=pd.read_csv('players_21_top_100.csv')
# Out:
# /var/folders/md/tn_62zhs5n50lbz66wqmxvzc0000gn/T/ipykernel_995/2431071262.py:1: DtypeWarning: Columns (1,2,3,5,8,9,10,16,17,21,22,23,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   players=pd.read_csv('players_21_top_100.csv')

# %%
pd.set_option('display.max_columns',False)

# %%
players.head(1)
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0   158023.0  https://sofifa.com/player/158023/lionel-messi/...  ...  52+3  62+3
#
# [1 rows x 106 columns]

# %%
# Creating a box plot

sns.boxplot(y=players['overall'])
# Out:
# <AxesSubplot:ylabel='overall'>

# %%
# Removing outliters by specifying fliersize=0

sns.boxplot(x=players['overall'], fliersize=0)
# Out:
# <AxesSubplot:xlabel='overall'>

# %%
# Adding an x and y axis argument 2 create a 2d box plot

sns.boxplot(y=players['overall'], x=players['league_name'])
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %%
# Changing the figure size with plt

plt.figure(figsize=(10,10))
sns.boxplot(y=players['overall'], x=players['league_name'])
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %%
# Violin Plot

plt.figure(figsize=(10,10))
sns.violinplot(y=players['overall'], x=players['league_name'])
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %% [markdown]
# # Strip Plot
# https://seaborn.pydata.org/generated/seaborn.stripplot.html

# %%
# Creating a Strip Plot

plt.figure(figsize=(10,10))
sns.stripplot(y=players['overall'], x=players['league_name'], color='black')
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %%
# Strip Plot with Box Plot
plt.figure(figsize=(10,10))
sns.stripplot(y=players['overall'], x=players['league_name'], color='black')
sns.boxplot(y=players['overall'], x=players['league_name'])
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %% [markdown]
# # Swarm Plot
# https://seaborn.pydata.org/generated/seaborn.swarmplot.html

# %%
# Creating a Swarm Plot

plt.figure(figsize=(10,10))
sns.swarmplot(y=players['overall'], x=players['league_name'])
# Out:
# <AxesSubplot:xlabel='league_name', ylabel='overall'>

# %% [markdown]
# # Point Plot
# https://seaborn.pydata.org/generated/seaborn.pointplot.html

# %%
# 1d Point Plot

sns.pointplot(x = players['overall'])
# Out:
# <AxesSubplot:xlabel='overall'>

# %%
# 2d Point Plot

sns.pointplot(x = players['overall'], y=players['preferred_foot'])
# Out:
# <AxesSubplot:xlabel='overall', ylabel='preferred_foot'>

# %%
# Adding a hue

sns.pointplot(x=players['overall'], hue=players['preferred_foot'], y = players['league_name'])
# Out:
# <AxesSubplot:xlabel='overall', ylabel='league_name'>
